# %%
import unittest

# %%
# %run gw_exp.ipynb
import unittest


class TestCP2Recursion(unittest.TestCase):

    def test_N_1(self):
        self.assertEqual(cp2_recursion(1), 1, "Should be 1")

    def test_N_2(self):
        self.assertEqual(cp2_recursion(2), 1, "Should be 1")

    def test_N_3(self):
        self.assertEqual(cp2_recursion(3), 12, "Should be 12")

    def test_N_4(self):
        self.assertEqual(cp2_recursion(4), 620, "Should be 620")

    def test_N_5(self):
        self.assertEqual(cp2_recursion(5), 87304, "Should be 87,304")

    def test_N_6(self):
        self.assertEqual(cp2_recursion(6), 26312976, "Should be 26,312,976")

    def test_N_7(self):
        self.assertEqual(cp2_recursion(7), 14616808192, "Should be 14,616,808,192")
   


def cp3_translate(d, k):
    k2 = 4*d - 2*k
    k3 = k
    return [2]*k2 + [3]*k3


class GWInvariantTest(unittest.TestCase):

    def test_N_1(self):
        self.assertEqual(cp2_recursion(1), 1, "Should be 1")

    def test_N_1_2(self):
        d, k = [1, 2]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 1)

    def test_N_1_1(self):
        d, k = [1, 1]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 1)

    def test_N_1_0(self):
        d, k = [1, 0]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 2)

    def test_N_2_4(self):
        d, k = [2, 4]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 0)

    def test_N_2_3(self):
        d, k = [2, 3]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 1)

    def test_N_2_2(self):
        d, k = [2, 2]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 4)

    def test_N_2_1(self):
        d, k = [2, 1]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 18)

    def test_N_2_0(self):
        d, k = [2, 0]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 92)

    def test_N_3_6(self):
        d, k = [3, 6]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 1)

    def test_N_3_5(self):
        d, k = [3, 5]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 5)

    def test_N_3_4(self):
        d, k = [3, 4]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 30)

    def test_N_3_3(self):
        d, k = [3, 3]
        self.assertEqual(gw_invariant(3, d, cp3_translate(d, k)), 190)

# %%
# %run ogw_exp.ipynb

def get_l1(n, b, k, l2, A1, A2):
    m = n - 3 + b*(n+1) + k + 2*l2 - k*n - 2*l2 * A2
    if (m % (2*(A1 - 1))) == 0:
        return int(m / (2*(A1 - 1)))
    else:
        assert False, "illegal input"


class TestOGWInvatiant(unittest.TestCase):

    def test_N_1(self):
        self.assertEqual(cp2_recursion(1), 1, "Should be 1")

    def test_no_points(self):
        A_list = [
            ([3, 3, 6], -2),
            ([3, 5, 10], 90),
            ([3, 7, 14], -29178),
            ([5, 5, 8], 2),
            #([5, 9, 14], 1974),
            #([5, 13, 20], 42781410),
            #([5, 17, 26], 7024726794150),
            #([7, 7, 10], -2),
            #([7, 13, 18], 35498),
            #([7, 19, 26], -40083246650),
            #([7, 25, 34], 680022893749060370),
            #([9, 9, 12], 2),
            #([9, 17, 22], 587334),
            #([9, 25, 32], 31424766229890),
            #([9, 33, 42], 49920592599715322910150),
            #([15, 15, 18], -2),
            #([15, 29, 34], 2247512778)
        ]

        for t in A_list:
            n = t[0][0]
            b = t[0][1]
            k = t[0][2]
            ogw = t[1]
            self.assertEqual(ogw_invariant(n, b, k, ClassList([]), ogw, \
                "For " + str(t) + ", value should be " + str(ogw))
    
    def test_n5_class2_class4(self):
        A_list = [
          # ([n, b, k, l2, Gamma_2, Gmma_4], result)
            ([5, 1, 0, 0, 2, 4], 1/8),
            ([5, 3, 0, 0, 2, 4], -43515/512),
            #([5, 5, 0, 0, 2, 4], 601224741985/32768),
            #([5, 7, 0, 0, 2, 4], -11623864227388947915/2097152),
            #([5, 9, 0, 0, 2, 4], 140294698313130485254672005681/134217728),

            ([5, 1, 0, 1, 2, 4], 1/2),
            ([5, 3, 0, 1, 2, 4], -255/32),
            #([5, 5, 0, 1, 2, 4], 602002259/1024),
            #([5, 7, 0, 1, 2, 4], 113202029455499631/131072),
            #([5, 9, 0, 1, 2, 4], 20113658490667274313737811/2097152),

            ([5, 1, 0, 2, 2, 4], 0),
            ([5, 3, 0, 2, 2, 4], -11/32),
            #([5, 5, 0, 2, 2, 4], 42354213/2048),
            #([5, 7, 0, 2, 2, 4], -1929681317485627/131072),
            #([5, 9, 0, 2, 2, 4], 797025207129184980573997/8388608),

            ([5, 1, 0, 3, 2, 4], 0),
            ([5, 3, 0, 3, 2, 4], 3/8),
            #([5, 5, 0, 3, 2, 4], 88007/128),
            #([5, 7, 0, 3, 2, 4], 136049411385/512),
            #([5, 9, 0, 3, 2, 4], 526360518604567156539/524288)
            ]
        
        for t in A_list:
            n = t[0][0]
            b = t[0][1]
            k = t[0][2]
            l2 = t[0][3]
            A1 = t[0][4]
            A2 = t[0][5]
            l1 = get_l1(n, b, k, l2, A1, A2)

            if l1 < 0:
                continue
            
            A = ClassList([A1] * l1 + [A2] * l2)
            ogw = t[1]

            self.assertEqual(ogw_invariant(n, b, k, A), ogw, \
                "For " + str(t) + ", value should be " + str(ogw))

    def test_n7_class2_class6(self):
        A_list = [ # ([n, b, k, l1, Gamma_2, Gmma_6], result)
            ([7, 1, 0, 0, 2, 6], -1/32),
            #([7, 3, 0, 0, 2, 6], -40990173/8192),
            #([7, 5, 0, 0, 2, 6], Rational('-679329355023877929/2097152')),
            #([7, 7, 0, 0, 2, 6], Rational('-304348375415626014616826203269/536870912')),

            ([7, 1, 0, 1, 2, 6], -1/2),
            ([7, 3, 0, 1, 2, 6], -23229/512),
            #([7, 5, 0, 1, 2, 6], Rational('-32941896518265/131072')),
            #([7, 7, 0, 1, 2, 6], Rational('-3267223276596315843861141/33554432')),

            ([7, 1, 0, 2, 2, 6], 0),
            ([7, 3, 0, 2, 2, 6], -11/32),
            #([7, 5, 0, 2, 2, 6], Rational('-2874828463/8192')),
            #([7, 7, 0, 2, 2, 6], Rational('-54161348711499099171/2097152')),

            ([7, 1, 0, 3, 2, 6], 0),
            ([7, 3, 0, 3, 2, 6], 0),
            ([7, 5, 0, 3, 2, 6], -338633/512),
            #([7, 7, 0, 3, 2, 6], Rational('-1318018642164857/131072')),
            ]
        
        for t in A_list:
            n = t[0][0]
            b = t[0][1]
            k = t[0][2]
            l2 = t[0][3]
            A1 = t[0][4]
            A2 = t[0][5]
            l1 = get_l1(n, b, k, l2, A1, A2)

            if l1 < 0:
                continue

            A = ClassList([A1] * l1 + [A2] * l2)
            ogw = t[1]
            self.assertEqual(ogw_invariant(n, b, k, A), ogw,\
                "For " + str(t) + " and l1 = " + str(l1) \
                    + ", value should be " + str(ogw))

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_N_1 (__main__.GWInvariantTest) ... ok
# test_N_1_0 (__main__.GWInvariantTest) ... ok
# test_N_1_1 (__main__.GWInvariantTest) ... ok
# test_N_1_2 (__main__.GWInvariantTest) ... ok
# test_N_2_0 (__main__.GWInvariantTest) ... ok
# test_N_2_1 (__main__.GWInvariantTest) ... ok
# test_N_2_2 (__main__.GWInvariantTest) ... ok
# test_N_2_3 (__main__.GWInvariantTest) ... ok
# test_N_2_4 (__main__.GWInvariantTest) ... ok
# test_N_3_3 (__main__.GWInvariantTest) ... ok
# test_N_3_4 (__main__.GWInvariantTest) ... ok
# test_N_3_5 (__main__.GWInvariantTest) ... ok
# test_N_3_6 (__main__.GWInvariantTest) ... ok
# test_N_1 (__main__.TestCP2Recursion) ... ok
# test_N_2 (__main__.TestCP2Recursion) ... ok
# test_N_3 (__main__.TestCP2Recursion) ... ok
# test_N_4 (__main__.TestCP2Recursion) ... ok
# test_N_5 (__main__.TestCP2Recursion) ... ok
# test_N_6 (__main__.TestCP2Recursion) ... ok
# test_N_7 (__main__.TestCP2Recursion) ... ok
# test_N_1 (__main__.TestOGWInvatiant) ... ok
# test_n5_class2_class4 (__main__.TestOGWInvatiant) ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 7, 0, (2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 3, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:5975)()
#     995             try:
# --> 996                 return self.cache[k]
#     997             except TypeError:  # k is not hashable
#
# KeyError: ((5, 6, 1, (2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3)), ())
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-d7cb9e148355> in <module>
# ----> 1 unittest.main(argv=[''], verbosity=Integer(2), exit=False)
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/main.py in __init__(self, module, defaultTest, argv, testRunner, testLoader, exit, verbosity, failfast, catchbreak, buffer, warnings, tb_locals)
#      99         self.progName = os.path.basename(argv[0])
#     100         self.parseArgs(argv)
# --> 101         self.runTests()
#     102
#     103     def usageExit(self, msg=None):
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/main.py in runTests(self)
#     269             # it is assumed to be a TestRunner instance
#     270             testRunner = self.testRunner
# --> 271         self.result = testRunner.run(self.test)
#     272         if self.exit:
#     273             sys.exit(not self.result.wasSuccessful())
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/runner.py in run(self, test)
#     174                 startTestRun()
#     175             try:
# --> 176                 test(result)
#     177             finally:
#     178                 stopTestRun = getattr(result, 'stopTestRun', None)
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/suite.py in __call__(self, *args, **kwds)
#      82
#      83     def __call__(self, *args, **kwds):
# ---> 84         return self.run(*args, **kwds)
#      85
#      86     def debug(self):
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/suite.py in run(self, result, debug)
#     120
#     121             if not debug:
# --> 122                 test(result)
#     123             else:
#     124                 test.debug()
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/suite.py in __call__(self, *args, **kwds)
#      82
#      83     def __call__(self, *args, **kwds):
# ---> 84         return self.run(*args, **kwds)
#      85
#      86     def debug(self):
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/suite.py in run(self, result, debug)
#     120
#     121             if not debug:
# --> 122                 test(result)
#     123             else:
#     124                 test.debug()
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/case.py in __call__(self, *args, **kwds)
#     734
#     735     def __call__(self, *args, **kwds):
# --> 736         return self.run(*args, **kwds)
#     737
#     738     def debug(self):
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/case.py in run(self, result)
#     674                 outcome.expecting_failure = expecting_failure
#     675                 with outcome.testPartExecutor(self, isTest=True):
# --> 676                     self._callTestMethod(testMethod)
#     677                 outcome.expecting_failure = False
#     678                 with outcome.testPartExecutor(self):
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/unittest/case.py in _callTestMethod(self, method)
#     631
#     632     def _callTestMethod(self, method):
# --> 633         method()
#     634
#     635     def _callTearDown(self):
#
# <ipython-input-152-feae8c15ccc4> in test_n5_class2_class4(self)
#      86             ogw = t[Integer(1)]
#      87
# ---> 88             self.assertEqual(ogw_invariant(n, b, k, A), ogw, \
#      89                 "For " + str(t) + ", value should be " + str(ogw))
#      90
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#      73
#      74     if l >= Integer(2):
# ---> 75         cor = ogw_invariant(n, b, k, (A[Integer(0)]-Integer(1), A[Integer(1)]+Integer(1)) + tuple(A[Integer(2):]))
#      76         col = Integer(0)
#      77         ool = Integer(0)
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#      49     if l > Integer(0) and A[Integer(0)] == Integer(1):
#      50         #A.pop(0)
# ---> 51         result = (b/Integer(2))*ogw_invariant(n, b, k, A[Integer(1):])
#      52         return result
#      53
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#      73
#      74     if l >= Integer(2):
# ---> 75         cor = ogw_invariant(n, b, k, (A[Integer(0)]-Integer(1), A[Integer(1)]+Integer(1)) + tuple(A[Integer(2):]))
#      76         col = Integer(0)
#      77         ool = Integer(0)
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#      49     if l > Integer(0) and A[Integer(0)] == Integer(1):
#      50         #A.pop(0)
# ---> 51         result = (b/Integer(2))*ogw_invariant(n, b, k, A[Integer(1):])
#      52         return result
#      53
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#      73
#      74     if l >= Integer(2):
# ---> 75         cor = ogw_invariant(n, b, k, (A[Integer(0)]-Integer(1), A[Integer(1)]+Integer(1)) + tuple(A[Integer(2):]))
#      76         col = Integer(0)
#      77         ool = Integer(0)
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#      49     if l > Integer(0) and A[Integer(0)] == Integer(1):
#      50         #A.pop(0)
# ---> 51         result = (b/Integer(2))*ogw_invariant(n, b, k, A[Integer(1):])
#      52         return result
#      53
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#     120                     k2 = k - k1
#     121                     ool += binomial(k, k1)*ogw_invariant(n, b1, k1, (Integer(1), A[Integer(0)]-Integer(1)) + tuple(I1)) \
# --> 122                         * ogw_invariant(n, b2, k2 + Integer(1), (A[Integer(1)],) + tuple(I2))
#     123
#     124         for t in I:
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# /var/tmp/sage-jc4b6yulaujayb9sr94ia88eourzeqip0oidmas3/local/lib/python3.8/site-packages/sage/misc/cachefunc.pyx in sage.misc.cachefunc.CachedFunction.__call__ (build/cythonized/sage/misc/cachefunc.c:6101)()
#     999                 return self.cache[k]
#    1000         except KeyError:
# -> 1001             w = self.f(*args, **kwds)
#    1002             self.cache[k] = w
#    1003             return w
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant_helper(n, b, k, A)
#     132                     k2 = k - k1
#     133
# --> 134                     oor += binomial(k, k1) * ogw_invariant(n, b1, k1, (Integer(1), A[Integer(1)]) + tuple(I1)) \
#     135                                 * ogw_invariant(n, b2, k2 + Integer(1), (A[Integer(0)] - Integer(1),) + tuple(I2))
#     136
#
# <ipython-input-152-ce80217bb56d> in ogw_invariant(n, b, k, A)
#     192
#     193 def ogw_invariant(n, b, k, A):
# --> 194     return ogw_invariant_helper(n, b, k, tuple(sorted(A)))
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:
